# %%
from utils import *

# %%
mae_df, rmse_df, val_maes_df = gather_metrics("./final_models/")
# Out:
# current model = mpnn_distance_concat
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# current model = gfcn_no_distance_concat
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = gfcn_distance_concat
# current model = gcn_no_distance_concat
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = gcn_distance
# current model = gcn_distance_concat
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = mpnn_no_distance_concat
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# current model = mpnn_distance
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = mpnn_no_distance
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = gcn_no_distance
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.

# %%
bar_plot(mae_df, save_name="mae.png")
bar_plot(rmse_df, save_name="rmse.png")
mae_plot(val_maes_df, "val_mae.png")

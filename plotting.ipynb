# %%
from utils import *

# %%
mae_df, rmse_df, val_maes_df = gather_metrics("./final_models/")
# Out:
# current model = mpnn_distance_concat
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# current model = gat_distance_concat
# current model = gcn_no_distance_concat
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = gcn_distance
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# current model = gcn_distance_concat
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = mpnn_no_distance_concat
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# current model = mpnn_distance
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = mpnn_no_distance
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = gcn_no_distance
# 	found val MAEs...
# 	val MAEs logged.
# ...

# %%
mae_df
# Out:
#                      model        mu     alpha      homo      lumo       gap  \
# 0     mpnn_distance_concat  0.021294  0.009543  0.015151  0.018187  0.014147
# 1   gcn_no_distance_concat  0.019851  0.004246  0.015126  0.016054  0.012843
# 2             gcn_distance  0.019101  0.003301  0.015056  0.016374  0.012585
# 3      gcn_distance_concat  0.018976  0.003606  0.014661  0.015370  0.012355
# 4  mpnn_no_distance_concat  0.023247  0.012266  0.019061  0.021159  0.016861
# 5            mpnn_distance  0.021430  0.009322  0.015204  0.018184  0.014099
# 6         mpnn_no_distance  0.023454  0.012054  0.019130  0.021026  0.016820
# 7          gcn_no_distance  0.019258  0.003139  0.015452  0.016111  0.012843
# 8   gat_no_distance_concat  0.018261  0.004450  0.016256  0.018261  0.014240
#
#          r2      zpve        u0      u298      h298      g298        cv
# 0  0.018501  0.016327  0.013193  0.013193  0.013193  0.013193  0.019559
# ...

# %%
bar_plot(mae_df, save_name="bar_no_distance.png", barwidth=0.15, distance=False)
bar_plot(mae_df, save_name="bar_with_distance.png", barwidth=0.15, distance=True)
mae_plot(val_maes_df, "val_mae.png")

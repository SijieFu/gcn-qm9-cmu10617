# %%
from utils import *

# %%
mae_df, rmse_df, val_maes_df = gather_metrics("./final_models/")
# Out:
# current model = mpnn_distance_concat
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# current model = gcn_no_distance_concat
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = gcn_distance
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# current model = gcn_distance_concat
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = mpnn_no_distance_concat
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# current model = mpnn_distance
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = mpnn_no_distance
# 	found test metric...
# 	test metric logged.
# 	found val MAEs...
# 	val MAEs logged.
# current model = gcn_no_distance
# 	found val MAEs...
# 	val MAEs logged.
# 	found test metric...
# 	test metric logged.
# ...

# %%
bar_plot(mae_df, save_name="bar_no_distance.png", barwidth=0.2, distance=False)
bar_plot(mae_df, save_name="bar_distance.png", barwidth=0.2, distance=True)
mae_plot(val_maes_df, "val_mae.png")
